# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

print(cv2.__version__)
# Out:
# 4.13.0

# %%
img = cv2.imread ("/Users/230363/Documents/image.jpeg")
cv2.imshow("My image", img)
cv2.waitKey(0)

# %%
img.shape

# %%
gimg = cv2.imread("/Users/230363/Documents/image.jpeg", cv2.IMREAD_GRAYSCALE)
cv2.imshow("Gray Scal Image Title", gimg)
cv2.waitKey(0)

# %%
color_image = cv2.imread ("/Users/230363/Documents/image.jpeg")
grayscale_image = cv2.cvtColor(color_image, cv2.COLOR_BGR2GRAY)
cv2.imshow ("/Users/230363/Documents/image.jpeg", grayscale_image)
cv2.waitKey(0)

# %%
color_image = cv2.imread("/Users/230363/Documents/image.jpeg")

grayscale_image = cv2.cvtColor(color_image, cv2.COLOR_BGR2GRAY)

_, binary_image = cv2.threshold(grayscale_image, 100, 150, cv2.THRESH_BINARY)

cv2.imshow("binary image",binary_image)


cv2.waitKey(0)
